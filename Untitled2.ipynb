# %% [markdown]
# <a href="https://colab.research.google.com/github/sanskriti17204/python_np/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn import datasets

# %%
irisdataset = datasets.load_breast_cancer()

# %%
print(irisdataset)

# %%
irisdataframe.describe()   #gives all the comparing calculations
# Out:
#        mean radius  mean texture  mean perimeter    mean area  \
# count   569.000000    569.000000      569.000000   569.000000
# mean     14.127292     19.289649       91.969033   654.889104
# std       3.524049      4.301036       24.298981   351.914129
# min       6.981000      9.710000       43.790000   143.500000
# 25%      11.700000     16.170000       75.170000   420.300000
# 50%      13.370000     18.840000       86.240000   551.100000
# 75%      15.780000     21.800000      104.100000   782.700000
# max      28.110000     39.280000      188.500000  2501.000000
#
#        mean smoothness  mean compactness  mean concavity  mean concave points  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# std           0.014064          0.052813        0.079720             0.038803
# min           0.052630          0.019380        0.000000             0.000000
# ...

# %%
#adding a column to a dataframe
irisdataframe['price'] = irisdataset.target
irisdataframe.head()
#removing a row
irisdataframe.drop(index=1,axis=0)
irisdataframe.drop(columns='mean radius', axis=1)
# Out:
#      mean texture  mean perimeter  mean area  mean smoothness  \
# 0           10.38          122.80     1001.0          0.11840
# 1           17.77          132.90     1326.0          0.08474
# 2           21.25          130.00     1203.0          0.10960
# 3           20.38           77.58      386.1          0.14250
# 4           14.34          135.10     1297.0          0.10030
# ..            ...             ...        ...              ...
# 564         22.39          142.00     1479.0          0.11100
# 565         28.25          131.20     1261.0          0.09780
# 566         28.08          108.30      858.1          0.08455
# 567         29.33          140.10     1265.0          0.11780
# 568         24.54           47.92      181.0          0.05263
#
#      mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0             0.27760         0.30010              0.14710         0.2419
# ...

# %%
#locating a row using index value
irisdataframe.iloc[2]
# Out:
# mean radius                  19.690000
# mean texture                 21.250000
# mean perimeter              130.000000
# mean area                  1203.000000
# mean smoothness               0.109600
# mean compactness              0.159900
# mean concavity                0.197400
# mean concave points           0.127900
# mean symmetry                 0.206900
# mean fractal dimension        0.059990
# radius error                  0.745600
# texture error                 0.786900
# perimeter error               4.585000
# area error                   94.030000
# smoothness error              0.006150
# compactness error             0.040060
# concavity error               0.038320
# concave points error          0.020580
# symmetry error                0.022500
# fractal dimension error       0.004571
# worst radius                 23.570000
# worst texture                25.530000
# worst perimeter             152.500000
# worst area                 1709.000000
# ...

# %%
#locating a particular column
print(irisdataframe.iloc[:,0])
print(irisdataframe.iloc[:,1])
print(irisdataframe.iloc[:,-1])
# Out:
# 0      10.38
# 1      17.77
# 2      21.25
# 3      20.38
# 4      14.34
#        ...
# 564    22.39
# 565    28.25
# 566    28.08
# 567    29.33
# 568    24.54
# Name: mean texture, Length: 569, dtype: float64
# 0      122.80
# 1      132.90
# 2      130.00
# 3       77.58
# 4      135.10
#         ...
# 564    142.00
# 565    131.20
# 566    108.30
# 567    140.10
# 568     47.92
# Name: mean perimeter, Length: 569, dtype: float64

# %%
irisdataframe.corr()
# Out:
#                          mean radius  mean texture  mean perimeter  mean area  \
# mean radius                 1.000000      0.323782        0.997855   0.987357
# mean texture                0.323782      1.000000        0.329533   0.321086
# mean perimeter              0.997855      0.329533        1.000000   0.986507
# mean area                   0.987357      0.321086        0.986507   1.000000
# mean smoothness             0.170581     -0.023389        0.207278   0.177028
# mean compactness            0.506124      0.236702        0.556936   0.498502
# mean concavity              0.676764      0.302418        0.716136   0.685983
# mean concave points         0.822529      0.293464        0.850977   0.823269
# mean symmetry               0.147741      0.071401        0.183027   0.151293
# mean fractal dimension     -0.311631     -0.076437       -0.261477  -0.283110
# radius error                0.679090      0.275869        0.691765   0.732562
# ...

# %%
type(irisdataset)
# Out:
# sklearn.utils._bunch.Bunch

# %%
irisdataframe= pd.DataFrame(irisdataset.data, columns = irisdataset.feature_names)
print(irisdataframe.head())  #prints first 5 rows
print(irisdataframe.shape)   #prints the shape of the dataset
#print(type(irisdataframe))   #tells the type of the dataframe
#print(irisdataframe.tail()) #prints last 5 rows
#print(irisdataframe.info())  #gives the info abput the dataframe
#print(irisdataframe.isnull())  #tells if there is any missing value
#print(irisdataframe.isnull().sum()) #tells the total number of missing values 
#print(irisdataframe.mean())
#print( irisdataframe.std())
#print(irisdataframe.min())
#print(irisdataframe.max())
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension  ...  worst radius  worst texture  worst perimeter  \
# ...

# %%
#csv file to panda dataframe
cities_df= pd.read_csv('/content/csvfile.csv')

# %%
type(cities_df)
# Out:
# pandas.core.frame.DataFrame

# %%
cities_df.head()
# Out:
#              name alpha-2 alpha-3  country-code     iso_3166-2   region  \
# 0     Afghanistan      AF     AFG             4  ISO 3166-2:AF     Asia
# 1  Ã
# land Islands      AX     ALA           248  ISO 3166-2:AX   Europe
# 2         Albania      AL     ALB             8  ISO 3166-2:AL   Europe
# 3         Algeria      DZ     DZA            12  ISO 3166-2:DZ   Africa
# 4  American Samoa      AS     ASM            16  ISO 3166-2:AS  Oceania
#
#         sub-region intermediate-region  region-code  sub-region-code  \
# 0    Southern Asia                 NaN        142.0             34.0
# 1  Northern Europe                 NaN        150.0            154.0
# 2  Southern Europe                 NaN        150.0             39.0
# 3  Northern Africa                 NaN          2.0             15.0
# 4        Polynesia                 NaN          9.0             61.0
#
#    intermediate-region-code
# 0                       NaN
# 1                       NaN
# ...

# %%
print(cities_df.shape)
print(cities_df.value_counts('region'))  #specifies the number of time that same value has been taken in tht particular column
print(cities_df.groupby('region').mean)  #group the values based on their mean
print(cities_df.count())   #counts the number of values
# Out:
# (249, 11)
# region
# Africa      60
# Americas    57
# Asia        51
# Europe      51
# Oceania     29
# dtype: int64
# <bound method GroupBy.mean of <pandas.core.groupby.generic.DataFrameGroupBy object at 0x7fda31db4d00>>
# name                        249
# alpha-2                     248
# alpha-3                     249
# country-code                249
# iso_3166-2                  249
# region                      248
# sub-region                  248
# intermediate-region         107
# region-code                 248
# sub-region-code             248
# intermediate-region-code    107
# dtype: int64

# %%
excel_df=pd.read_excel('/content/country_full.xlsx')
print(excel_df.head())
# Out:
#                    name alpha-2 alpha-3  country-code     iso_3166-2   region  \
# 0           Afghanistan      AF     AFG             4  ISO 3166-2:AF     Asia
# 1  Ã_x0085_land Islands      AX     ALA           248  ISO 3166-2:AX   Europe
# 2               Albania      AL     ALB             8  ISO 3166-2:AL   Europe
# 3               Algeria      DZ     DZA            12  ISO 3166-2:DZ   Africa
# 4        American Samoa      AS     ASM            16  ISO 3166-2:AS  Oceania
#
#         sub-region intermediate-region  region-code  sub-region-code  \
# 0    Southern Asia                 NaN        142.0             34.0
# 1  Northern Europe                 NaN        150.0            154.0
# 2  Southern Europe                 NaN        150.0             39.0
# 3  Northern Africa                 NaN          2.0             15.0
# 4        Polynesia                 NaN          9.0             61.0
#
#    intermediate-region-code
# 0                       NaN
# ...

# %%
#exporting a dataframe to csv file
irisdataframe.to_csv('iris.csv')

# %%
#exporting a dataframe to excel file
irisdataframe.to_excel('iris.xlsx')

# %%
#creating a dataframe with random values
rand_df=pd.DataFrame(np.random.rand(20,10))
rand_df.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.696972  0.873038  0.278654  0.054774  0.072346  0.213165  0.176459
# 1  0.488443  0.664842  0.731896  0.029225  0.041583  0.474428  0.468107
# 2  0.133114  0.301772  0.716572  0.701170  0.217174  0.746369  0.106089
# 3  0.328911  0.842401  0.927399  0.098043  0.492615  0.452852  0.965302
# 4  0.050829  0.258301  0.969762  0.961867  0.466325  0.280689  0.534739
#
#           7         8         9
# 0  0.013276  0.683320  0.667890
# 1  0.850413  0.426637  0.470981
# 2  0.991388  0.176816  0.947177
# 3  0.998477  0.806200  0.922046
# 4  0.355300  0.638871  0.294230

# %%
print(rand_df.shape)
print(type(rand_df))
# Out:
# (20, 10)
# <class 'pandas.core.frame.DataFrame'>
